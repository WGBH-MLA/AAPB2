# %%
from cmless.parse import parse_collections

# %%
collections = parse_collections('../app/views/special_collections')
len(collections)
collections[0]

# %%
with open('../collections.json', 'w') as f:
    import json

    json.dump([c.model_dump(by_alias=True) for c in collections], f, indent=2)

# %%
from cmless.parse import parse_exhibits

# %%
exhibits = parse_exhibits("../app/views/exhibits")

# %%
# len(exhibits)
# from rich import print
# print(exhibits[2])

# %%
with open("exhibits.json", "w") as f:
    from json import dumps

    f.write(dumps([exhibit.model_dump(by_alias=True) for exhibit in exhibits]))
